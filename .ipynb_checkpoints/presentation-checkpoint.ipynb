# %% [markdown]
# ## Numerical Floquet
#
# Welcome to this Jupyter notebook.
# We will analyze the stability of periodic dynamical systems.

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://conda.binstar.org/chria
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.21.5)
# Collecting assimulo
#   Downloading Assimulo-3.0.tar.gz (1.6 MB)
#   Downloading Assimulo-2.9.zip (1.8 MB)
# Collecting simpy
#   Downloading simpy-4.0.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: tensorflow in c:\users\admin\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (2.9.1)
# Requirement already satisfied: keras-tuner in c:\users\admin\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.1.3)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.7.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.42.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (4.1.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (3.19.1)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (61.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (2.9.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.12)
# Requirement already satisfied: packaging in c:\users\admin\appdata\roaming\python\python39\site-packages (from tensorflow->-r requirements.txt (line 5)) (23.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (3.3.0)
# Requirement already satisfied: ipython in c:\users\admin\appdata\roaming\python\python39\site-packages (from keras-tuner->-r requirements.txt (line 6)) (8.11.0)
# Requirement already satisfied: kt-legacy in c:\users\admin\anaconda3\lib\site-packages (from keras-tuner->-r requirements.txt (line 6)) (1.0.4)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from keras-tuner->-r requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 5)) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\admin\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests->keras-tuner->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->keras-tuner->-r requirements.txt (line 6)) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->keras-tuner->-r requirements.txt (line 6)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->keras-tuner->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (3.0.38)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (2.14.0)
# Requirement already satisfied: decorator in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: backcall in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: pickleshare in c:\users\admin\appdata\roaming\python\python39\site-packages (from ipython->keras-tuner->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython->keras-tuner->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\admin\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->keras-tuner->-r requirements.txt (line 6)) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from stack-data->ipython->keras-tuner->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from stack-data->ipython->keras-tuner->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\admin\appdata\roaming\python\python39\site-packages (from stack-data->ipython->keras-tuner->-r requirements.txt (line 6)) (0.2.2)
# Building wheels for collected packages: assimulo
#   Building wheel for assimulo (setup.py): started
#   Building wheel for assimulo (setup.py): finished with status 'error'
#   Running setup.py clean for assimulo
# Failed to build assimulo
# Installing collected packages: simpy, assimulo
#     Running setup.py install for assimulo: started
#     Running setup.py install for assimulo: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\admin\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\admin\AppData\Local\Temp\pip-pip-egg-info-x4ohjsrs'
#          cwd: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\
#     Complete output (73 lines):
#     DEBUG:setup.py called with the following optional args
#      {'blas_home': '', 'lapack_home': '', 'plugins_home': '', 'sundials_home': '', 'superlu_home': '', 'blas_name': 'blas', 'extra_c_flags': '', 'with_openmp': False, 'is_static': False, 'sundials_with_superlu': None, 'debug': False, 'force_32bit': False, 'no_msvcr': False, 'log': 'NOTSET', 'log_file': None, 'prefix': None, 'extra_fortran_link_flags': '', 'extra_fortran_link_files': '', 'version': 'Default'}
#      argument parsing completed.
#     DEBUG:Source from svn revision unknow
#     DEBUG:Python version used: 3.9.12
#     DEBUG:Platform win
#     WARNING:No path to BLAS supplied, disabling support. View more information using --log=DEBUG
#     DEBUG:usage: --blas-home=path
#     DEBUG:Note: the path required is to where the static library lib is found
#     WARNING:No path to SuperLU supplied, disabling support. View more information using --log=DEBUG
#     DEBUG:No path to SuperLU supplied, SUNDIALS will not be compiled with support for SuperLU.
#     DEBUG:usage: --superlu-home=path
#     DEBUG:Note: the path required is to the folder where the folders 'SRC' and 'lib' are found.
#     WARNING:Could not find Sundials, check the provided path (--sundials-home=) to see that it actually points to Sundials.
#     DEBUG:Could not find cvodes.h in cvodes
#     WARNING:No path to LAPACK supplied, disabling support. View more information using --log=DEBUG
#     DEBUG:usage: --lapack-home=path
#     DEBUG:Note: the path required is to where the static library lib is found
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\algebraic.pxd
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\explicit_ode.pxd
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\implicit_ode.pxd
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\ode.pxd
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\problem.pyx
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\special_systems.pyx
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\support.pyx
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     Compiling assimulo\algebraic.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     Compiling assimulo\explicit_ode.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     Compiling assimulo\implicit_ode.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     Compiling assimulo\ode.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     Compiling assimulo\problem.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     Compiling assimulo\special_systems.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     Compiling assimulo\support.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     [1/7] Cythonizing assimulo\algebraic.pyx
#     [2/7] Cythonizing assimulo\explicit_ode.pyx
#     [3/7] Cythonizing assimulo\implicit_ode.pyx
#     [4/7] Cythonizing assimulo\ode.pyx
#     [5/7] Cythonizing assimulo\problem.pyx
#     [6/7] Cythonizing assimulo\special_systems.pyx
#     [7/7] Cythonizing assimulo\support.pyx
#     C:\Users\admin\anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_66f1455d14ab4b6cbe024e1d46f0d843\assimulo\solvers\euler.pyx
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     Compiling assimulo\solvers\euler.pyx because it depends on C:\Users\admin\anaconda3\lib\site-packages\numpy\__init__.pxd.
#     [1/1] Cythonizing assimulo\solvers\euler.pyx
#     WARNING:Could not find Blas or Lapack, disabling support for the solver GLIMDA.
#     DEBUG:['thirdparty\\hairer\\LICENSE_HAIRER', 'lib\\hairer\\LICENSE_HAIRER', 'thirdparty\\glimda\\LICENSE_GLIMDA', 'lib\\glimda\\LICENSE_GLIMDA', 'thirdparty\\odepack\\LICENSE_ODEPACK', 'lib\\odepack\\LICENSE_ODEPACK', 'thirdparty\\odassl\\LICENSE_ODASSL', 'lib\\odassl\\LICENSE_ODASSL', 'thirdparty\\dasp3\\LICENSE_DASP3', 'lib\\dasp3\\LICENSE_DASP3']
#     non-existing path in '': 'assimulo\\thirdparty\\hairer\\dopri5.pyf'
#     non-existing path in '': 'assimulo\\thirdparty\\hairer\\rodas_decsol.pyf'
#     non-existing path in '': 'assimulo\\thirdparty\\hairer\\radau_decsol.pyf'
#     non-existing path in '': 'assimulo\\thirdparty\\hairer\\radar5.pyf'
#     non-existing path in '': 'assimulo\\thirdparty\\odepack\\odepack.pyf'
#     non-existing path in '': 'assimulo\\thirdparty\\odassl\\odassl.pyf'
#     running egg_info
#     running build_src
#     build_src
#     building extension "assimulo.algebraic" sources
#     building extension "assimulo.explicit_ode" sources
#     building extension "assimulo.implicit_ode" sources
#     building extension "assimulo.ode" sources
#     building extension "assimulo.problem" sources
#     building extension "assimulo.special_systems" sources
#     building extension "assimulo.support" sources
#     building extension "assimulo.solvers.euler" sources
#     building extension "assimulo.lib.dopri5" sources
#       target build\src.win-amd64-3.9\assimulo\thirdparty\hairer\dopri5module.c does not exist:
#        Assuming dopri5module.c was generated with "build_src --inplace" command.
#     error: 'assimulo\\thirdparty\\hairer\\dopri5module.c' missing
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/28/ef/4d8b15a0842410bb4ca8f500dadd5ff76fb3e34559f956a51c19b8a4912b/Assimulo-3.0.tar.gz#sha256=61cdca4562745078c966cc4fab44d8bc0db11a9e6856b45c470ac65c16af9e8a (from https://pypi.org/simple/assimulo/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\admin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\admin\AppData\Local\Temp\pip-wheel-vf77uvs8'
#        cwd: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\
#   Complete output (177 lines):
#   DEBUG:setup.py called with the following optional args
#    {'blas_home': '', 'lapack_home': '', 'plugins_home': '', 'sundials_home': '', 'superlu_home': '', 'blas_name': 'blas', 'extra_c_flags': '', 'is_static': False, 'sundials_with_superlu': False, 'debug': False, 'force_32bit': False, 'no_msvcr': False, 'log': 'NOTSET', 'log_file': None, 'prefix': None, 'extra_fortran_link_flags': '', 'extra_fortran_link_files': ''}
#    argument parsing completed.
#   DEBUG:Source from svn revision unknow
#   DEBUG:Python version used: 3.9.12
#   DEBUG:Platform win
#   WARNING:No path to BLAS supplied, disabling support. View more information using --log=DEBUG
#   DEBUG:usage: --blas-home=path
#   DEBUG:Note: the path required is to where the static library lib is found
#   WARNING:KINSOL will not be compiled with support for SuperLU as BLAS is missing.
#   WARNING:Could not find Sundials, check the provided path (--sundials-home=) to see that it actually points to Sundials.
#   DEBUG:Could not find cvodes.h in cvodes
#   WARNING:No path to LAPACK supplied, disabling support. View more information using --log=DEBUG
#   DEBUG:usage: --lapack-home=path
#   DEBUG:Note: the path required is to where the static library lib is found
#   C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\setup.py:439: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if StrictVersion(np.version.version) > StrictVersion("1.6.1"):
#   C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\setup.py:467: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if StrictVersion(np.version.version) > StrictVersion("1.6.1"): #NOTE, THERE IS A PROBLEM WITH PASSING F77 COMPILER ARGS FOR NUMPY LESS THAN 1.6.1, DISABLE FOR NOW
#   WARNING:Could not find Blas or Lapack, disabling support for the solver GLIMDA.
#   DEBUG:['thirdparty\\hairer\\LICENSE_HAIRER', 'lib\\hairer\\LICENSE_HAIRER', 'thirdparty\\glimda\\LICENSE_GLIMDA', 'lib\\glimda\\LICENSE_GLIMDA', 'thirdparty\\odepack\\LICENSE_ODEPACK', 'lib\\odepack\\LICENSE_ODEPACK', 'thirdparty\\odassl\\LICENSE_ODASSL', 'lib\\odassl\\LICENSE_ODASSL', 'thirdparty\\dasp3\\LICENSE_DASP3', 'lib\\dasp3\\LICENSE_DASP3']
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building extension "assimulo.algebraic" sources
#   building extension "assimulo.explicit_ode" sources
#   building extension "assimulo.implicit_ode" sources
#   building extension "assimulo.ode" sources
#   building extension "assimulo.problem" sources
#   building extension "assimulo.special_systems" sources
#   building extension "assimulo.support" sources
#   building extension "assimulo.solvers.euler" sources
#   building extension "assimulo.lib.dopri5" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\dopri5-f2pywrappers.f' to sources.
#   building extension "assimulo.lib.rodas" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\rodas-f2pywrappers.f' to sources.
#   building extension "assimulo.lib.radau5" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\radau5-f2pywrappers.f' to sources.
#   building extension "assimulo.lib.radar5" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\radar5-f2pywrappers.f' to sources.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\radar5-f2pywrappers2.f90' to sources.
#   building extension "assimulo.lib.odepack" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odepack\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odepack' to include_dirs.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\odepack\odepack-f2pywrappers.f' to sources.
#   building extension "assimulo.lib.odassl" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odassl\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odassl' to include_dirs.
#   building extension "assimulo.lib.dasp3dp" sources
#   f2py options: []
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\dasp3\fortranobject.c' to sources.
#     adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\dasp3' to include_dirs.
#     adding 'build\src.win-amd64-3.9\assimulo\thirdparty\dasp3\dasp3dp-f2pywrappers.f' to sources.
#   build_src: building npy-pkg config files
#   C:\Users\admin\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build_py
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\assimulo
#   copying assimulo\exception.py -> build\lib.win-amd64-3.9\assimulo
#   copying assimulo\kinsol.py -> build\lib.win-amd64-3.9\assimulo
#   copying assimulo\problem_algebraic.py -> build\lib.win-amd64-3.9\assimulo
#   copying assimulo\__init__.py -> build\lib.win-amd64-3.9\assimulo
#   creating build\lib.win-amd64-3.9\assimulo\lib
#   copying assimulo\lib\radau_core.py -> build\lib.win-amd64-3.9\assimulo\lib
#   copying assimulo\lib\__init__.py -> build\lib.win-amd64-3.9\assimulo\lib
#   creating build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\dasp3.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\glimda.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\odassl.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\odepack.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\radar5.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\radau5.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\rosenbrock.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\runge_kutta.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   copying assimulo\solvers\__init__.py -> build\lib.win-amd64-3.9\assimulo\solvers
#   creating build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_basic_backward.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_gyro.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_stability.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_initial_sensitivity.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_jac.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_jac_spgmr.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_parameters.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_parameters_fcn.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_parameters_modified.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\cvode_with_preconditioning.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\dasp3_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\dopri5_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\dopri5_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\euler_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\euler_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\euler_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\glimda_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_basic_backward.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_with_initial_sensitivity.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_with_jac.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_with_jac_spgmr.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_with_parameters.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\ida_with_user_defined_handle_result.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\kinsol_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\kinsol_ors.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\kinsol_with_jac.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\lsodar_bouncing_ball.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\lsodar_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\lsodar_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\mech_system_pendulum.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\radar_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\radau5dae_time_events.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\radau5dae_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\radau5ode_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\radau5ode_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\rodasode_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\rungekutta34_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\rungekutta34_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\rungekutta4_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#   copying assimulo\examples\__init__.py -> build\lib.win-amd64-3.9\assimulo\examples
#   creating build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\test_examples.py -> build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\test_explicit_ode.py -> build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\test_implicit_ode.py -> build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\test_KINSOL.py -> build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\test_ode.py -> build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\test_solvers.py -> build\lib.win-amd64-3.9\assimulo\tests
#   copying assimulo\tests\__init__.py -> build\lib.win-amd64-3.9\assimulo\tests
#   creating build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_euler.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_glimda.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_kinsol.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_odepack.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_radau5.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_rosenbrock.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_rungekutta.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\test_sundials.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\tests\solvers\__init__.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#   copying assimulo\version.txt -> build\lib.win-amd64-3.9\assimulo
#   creating build\lib.win-amd64-3.9\assimulo\thirdparty
#   creating build\lib.win-amd64-3.9\assimulo\thirdparty\hairer
#   copying assimulo\thirdparty\hairer\LICENSE_HAIRER -> build\lib.win-amd64-3.9\assimulo\thirdparty\hairer
#   creating build\lib.win-amd64-3.9\assimulo\thirdparty\glimda
#   copying assimulo\thirdparty\glimda\LICENSE_GLIMDA -> build\lib.win-amd64-3.9\assimulo\thirdparty\glimda
#   creating build\lib.win-amd64-3.9\assimulo\thirdparty\odepack
#   copying assimulo\thirdparty\odepack\LICENSE_ODEPACK -> build\lib.win-amd64-3.9\assimulo\thirdparty\odepack
#   creating build\lib.win-amd64-3.9\assimulo\thirdparty\odassl
#   copying assimulo\thirdparty\odassl\LICENSE_ODASSL -> build\lib.win-amd64-3.9\assimulo\thirdparty\odassl
#   creating build\lib.win-amd64-3.9\assimulo\thirdparty\dasp3
#   copying assimulo\thirdparty\dasp3\LICENSE_DASP3 -> build\lib.win-amd64-3.9\assimulo\thirdparty\dasp3
#   copying assimulo\examples\kinsol_ors_matrix.mtx -> build\lib.win-amd64-3.9\assimulo\examples
#   running build_ext
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   customize MSVCCompiler using build_ext
#   CCompilerOpt.cc_test_flags[1013] : testing flags (/O2)
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   CCompilerOpt.cache_flush[809] : write cache to path -> C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\build\temp.win-amd64-3.9\Release\ccompiler_opt_cache_ext.py
#   ----------------------------------------
#   ERROR: Failed building wheel for assimulo
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\admin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\admin\AppData\Local\Temp\pip-record-xlis9hyk\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\admin\anaconda3\Include\assimulo'
#          cwd: C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\
#     Complete output (177 lines):
#     DEBUG:setup.py called with the following optional args
#      {'blas_home': '', 'lapack_home': '', 'plugins_home': '', 'sundials_home': '', 'superlu_home': '', 'blas_name': 'blas', 'extra_c_flags': '', 'is_static': False, 'sundials_with_superlu': False, 'debug': False, 'force_32bit': False, 'no_msvcr': False, 'log': 'NOTSET', 'log_file': None, 'prefix': None, 'extra_fortran_link_flags': '', 'extra_fortran_link_files': ''}
#      argument parsing completed.
#     DEBUG:Source from svn revision unknow
#     DEBUG:Python version used: 3.9.12
#     DEBUG:Platform win
#     WARNING:No path to BLAS supplied, disabling support. View more information using --log=DEBUG
#     DEBUG:usage: --blas-home=path
#     DEBUG:Note: the path required is to where the static library lib is found
#     WARNING:KINSOL will not be compiled with support for SuperLU as BLAS is missing.
#     WARNING:Could not find Sundials, check the provided path (--sundials-home=) to see that it actually points to Sundials.
#     DEBUG:Could not find cvodes.h in cvodes
#     WARNING:No path to LAPACK supplied, disabling support. View more information using --log=DEBUG
#     DEBUG:usage: --lapack-home=path
#     DEBUG:Note: the path required is to where the static library lib is found
#     C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\setup.py:439: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       if StrictVersion(np.version.version) > StrictVersion("1.6.1"):
#     C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\setup.py:467: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       if StrictVersion(np.version.version) > StrictVersion("1.6.1"): #NOTE, THERE IS A PROBLEM WITH PASSING F77 COMPILER ARGS FOR NUMPY LESS THAN 1.6.1, DISABLE FOR NOW
#     WARNING:Could not find Blas or Lapack, disabling support for the solver GLIMDA.
#     DEBUG:['thirdparty\\hairer\\LICENSE_HAIRER', 'lib\\hairer\\LICENSE_HAIRER', 'thirdparty\\glimda\\LICENSE_GLIMDA', 'lib\\glimda\\LICENSE_GLIMDA', 'thirdparty\\odepack\\LICENSE_ODEPACK', 'lib\\odepack\\LICENSE_ODEPACK', 'thirdparty\\odassl\\LICENSE_ODASSL', 'lib\\odassl\\LICENSE_ODASSL', 'thirdparty\\dasp3\\LICENSE_DASP3', 'lib\\dasp3\\LICENSE_DASP3']
#     running install
#     C:\Users\admin\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building extension "assimulo.algebraic" sources
#     building extension "assimulo.explicit_ode" sources
#     building extension "assimulo.implicit_ode" sources
#     building extension "assimulo.ode" sources
#     building extension "assimulo.problem" sources
#     building extension "assimulo.special_systems" sources
#     building extension "assimulo.support" sources
#     building extension "assimulo.solvers.euler" sources
#     building extension "assimulo.lib.dopri5" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\dopri5-f2pywrappers.f' to sources.
#     building extension "assimulo.lib.rodas" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\rodas-f2pywrappers.f' to sources.
#     building extension "assimulo.lib.radau5" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\radau5-f2pywrappers.f' to sources.
#     building extension "assimulo.lib.radar5" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\hairer' to include_dirs.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\radar5-f2pywrappers.f' to sources.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\hairer\radar5-f2pywrappers2.f90' to sources.
#     building extension "assimulo.lib.odepack" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odepack\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odepack' to include_dirs.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\odepack\odepack-f2pywrappers.f' to sources.
#     building extension "assimulo.lib.odassl" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odassl\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\odassl' to include_dirs.
#     building extension "assimulo.lib.dasp3dp" sources
#     f2py options: []
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\dasp3\fortranobject.c' to sources.
#       adding 'build\src.win-amd64-3.9\build\src.win-amd64-3.9\assimulo\thirdparty\dasp3' to include_dirs.
#       adding 'build\src.win-amd64-3.9\assimulo\thirdparty\dasp3\dasp3dp-f2pywrappers.f' to sources.
#     build_src: building npy-pkg config files
#     running build_py
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\assimulo
#     copying assimulo\exception.py -> build\lib.win-amd64-3.9\assimulo
#     copying assimulo\kinsol.py -> build\lib.win-amd64-3.9\assimulo
#     copying assimulo\problem_algebraic.py -> build\lib.win-amd64-3.9\assimulo
#     copying assimulo\__init__.py -> build\lib.win-amd64-3.9\assimulo
#     creating build\lib.win-amd64-3.9\assimulo\lib
#     copying assimulo\lib\radau_core.py -> build\lib.win-amd64-3.9\assimulo\lib
#     copying assimulo\lib\__init__.py -> build\lib.win-amd64-3.9\assimulo\lib
#     creating build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\dasp3.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\glimda.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\odassl.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\odepack.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\radar5.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\radau5.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\rosenbrock.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\runge_kutta.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     copying assimulo\solvers\__init__.py -> build\lib.win-amd64-3.9\assimulo\solvers
#     creating build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_basic_backward.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_gyro.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_stability.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_initial_sensitivity.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_jac.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_jac_spgmr.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_parameters.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_parameters_fcn.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_parameters_modified.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\cvode_with_preconditioning.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\dasp3_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\dopri5_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\dopri5_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\euler_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\euler_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\euler_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\glimda_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_basic_backward.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_with_initial_sensitivity.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_with_jac.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_with_jac_spgmr.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_with_parameters.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\ida_with_user_defined_handle_result.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\kinsol_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\kinsol_ors.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\kinsol_with_jac.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\lsodar_bouncing_ball.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\lsodar_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\lsodar_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\mech_system_pendulum.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\radar_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\radau5dae_time_events.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\radau5dae_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\radau5ode_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\radau5ode_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\rodasode_vanderpol.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\rungekutta34_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\rungekutta34_with_disc.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\rungekutta4_basic.py -> build\lib.win-amd64-3.9\assimulo\examples
#     copying assimulo\examples\__init__.py -> build\lib.win-amd64-3.9\assimulo\examples
#     creating build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\test_examples.py -> build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\test_explicit_ode.py -> build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\test_implicit_ode.py -> build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\test_KINSOL.py -> build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\test_ode.py -> build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\test_solvers.py -> build\lib.win-amd64-3.9\assimulo\tests
#     copying assimulo\tests\__init__.py -> build\lib.win-amd64-3.9\assimulo\tests
#     creating build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_euler.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_glimda.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_kinsol.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_odepack.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_radau5.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_rosenbrock.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_rungekutta.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\test_sundials.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\tests\solvers\__init__.py -> build\lib.win-amd64-3.9\assimulo\tests\solvers
#     copying assimulo\version.txt -> build\lib.win-amd64-3.9\assimulo
#     creating build\lib.win-amd64-3.9\assimulo\thirdparty
#     creating build\lib.win-amd64-3.9\assimulo\thirdparty\hairer
#     copying assimulo\thirdparty\hairer\LICENSE_HAIRER -> build\lib.win-amd64-3.9\assimulo\thirdparty\hairer
#     creating build\lib.win-amd64-3.9\assimulo\thirdparty\glimda
#     copying assimulo\thirdparty\glimda\LICENSE_GLIMDA -> build\lib.win-amd64-3.9\assimulo\thirdparty\glimda
#     creating build\lib.win-amd64-3.9\assimulo\thirdparty\odepack
#     copying assimulo\thirdparty\odepack\LICENSE_ODEPACK -> build\lib.win-amd64-3.9\assimulo\thirdparty\odepack
#     creating build\lib.win-amd64-3.9\assimulo\thirdparty\odassl
#     copying assimulo\thirdparty\odassl\LICENSE_ODASSL -> build\lib.win-amd64-3.9\assimulo\thirdparty\odassl
#     creating build\lib.win-amd64-3.9\assimulo\thirdparty\dasp3
#     copying assimulo\thirdparty\dasp3\LICENSE_DASP3 -> build\lib.win-amd64-3.9\assimulo\thirdparty\dasp3
#     copying assimulo\examples\kinsol_ors_matrix.mtx -> build\lib.win-amd64-3.9\assimulo\examples
#     running build_ext
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     customize MSVCCompiler using build_ext
#     CCompilerOpt.cc_test_flags[1013] : testing flags (/O2)
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     CCompilerOpt.cache_flush[809] : write cache to path -> C:\Users\admin\AppData\Local\Temp\pip-install-c9029vvj\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\build\temp.win-amd64-3.9\Release\ccompiler_opt_cache_ext.py
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\admin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-c9029vvj\\assimulo_18d8177a410641cc9f6eb70f0f3ec3c9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\admin\AppData\Local\Temp\pip-record-xlis9hyk\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\admin\anaconda3\Include\assimulo' Check the logs for full command output.
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)

# %%
import differential_equations
import numerical_integration
import matplotlib.pyplot as plt
import numpy as np

# %%
t_eval = np.linspace(0, 20, 2000)

# %%
initial_value = 0
